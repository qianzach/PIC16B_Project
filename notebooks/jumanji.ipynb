# %%
import networkx as nx
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
url = "web_scraper/jumanji.csv"
df = pd.read_csv(url)
df.head(15)
# Out:
#             actor                movie_or_TV_name
# 0   Morgan Turner         Jumanji: The Next Level
# 1   Morgan Turner  Jumanji: Welcome to the Jungle
# 2   Morgan Turner                    Wonderstruck
# 3   Morgan Turner             Halal in the Family
# 4   Morgan Turner                        Quitters
# 5   Morgan Turner         The Sisterhood of Night
# 6   Morgan Turner     A Miracle in Spanish Harlem
# 7   Morgan Turner                     Blue Bloods
# 8   Morgan Turner                     Spring/Fall
# 9   Morgan Turner                  Mildred Pierce
# 10  Morgan Turner                           Mercy
# 11  Morgan Turner                     Remember Me
# 12  Morgan Turner                  The Answer Man
# 13  Morgan Turner                     Inseparable
# 14  Morgan Turner                      Invincible

# %%
len(df.actor.unique())
# Out:
# 88

# %%
df.shape
# Out:
# (3398, 2)

# %%
G = nx.from_pandas_edgelist(df.iloc[0:3398], 
                             source = "movie_or_TV_name", 
                             target = "actor", 
                             edge_attr=None, 
                             create_using=nx.DiGraph())

# %%
to_be_removed = [x for  x in G.nodes() if (G.degree(x) <= 5 or G.degree(x) > 50)]

# %%
for x in to_be_removed:
    G.remove_node(x)

# %%
colors = []
for node in G:
    if node in df["actor"].values:
        colors.append("lightblue") # Actor
    else: colors.append("red") # Project Title

# %%
deg = G.degree()
plt.figure(figsize=(20, 20))
layout = nx.layout.spring_layout(G)
nx.draw(G, layout,
        with_labels=True, 
        node_color = colors,
        node_size  = [500*deg[i] for i in G.nodes()])

# %%
sorted(G.degree, key=lambda x: x[1], reverse=True)
# Out:
# [('John Gettier', 11),
#  ('Matthew Byrge', 8),
#  ('Shane Berengue', 8),
#  ('Black Lightning', 7),
#  ('Jumanji: Welcome to the Jungle', 6),
#  ('Doom Patrol', 6),
#  ('Dynasty', 6),
#  ('Ozark', 6),
#  ('Bad Boys for Life', 6),
#  ('The Outsider', 6),
#  ('MacGyver', 6),
#  ('Shiquita James', 6),
#  ('James William Ballard', 6),
#  ('The Gifted', 5),
#  ('The Suicide Squad', 5),
#  ('Richard Jewell', 5),
#  ('Scott Rapp', 5),
#  ('Red Notice', 5),
#  ('The Tomorrow War', 5),
#  ('Melissa Kennemore', 5),
#  ('Christine A. Jordan', 5),
#  ('The Resident', 4),
#  ('The Walking Dead', 4),
#  ('Morgan Brown', 4),
#  ('Stuber', 3),
#  ('Superintelligence', 3),
#  ('Paul Pillsbury', 3),
#  ('Elizabeth Sparks', 2),
#  ('Brandon Parker', 2),
#  ('Jared Hasmuk', 2),
#  ('Tahseen Ghauri', 2),
#  ('Matt Bolick', 2),
#  ('Vanessa Cater', 2),
#  ('Jennifer Patino', 2),
#  ('Morgan Turner', 1),
#  ('Madison Iseman', 1),
#  ('Alex Wolff', 1),
#  ("Ser'Darius Blain", 1),
#  ('Kodai Yamaguchi', 1),
#  ('Lewis Wright', 1),
#  ('Ulrike Stewart', 1),
#  ('Bruno Rose', 1),
#  ('Sean K. Jones', 1),
#  ('Rodney L. James', 1),
#  ('Brent Moorer Gaskins', 1),
#  ('Bethany Dixon', 1),
#  ('John David Bulla', 1),
#  ('Awkwafina', 0),
#  ('Kevin Hart', 0),
#  ('Rory McCann', 0),
#  ('Trinity Whiteside', 0),
#  ('Ashley Scott', 0),
#  ('Monica Powers', 0),
#  ('Andrew R. McCallister', 0),
#  ('Michael Mathis', 0),
#  ('Sal Longobardo', 0),
#  ('Marché Day', 0),
#  ('Catherine Busby', 0),
#  ('Ray Buchanan', 0),
#  ('Dillon Belisle', 0),
#  ('Cruz Abelita', 0),
#  ('Richard Baxter', 0),
#  ('Lucy DeVito', 0),
#  ('Anthony Neves', 0),
#  ('Deobia Oparei', 0),
#  ('Leslie Simms', 0),
#  ('Javier Villamil', 0),
#  ('Madison Johnson', 0),
#  ('Dorothy Steel', 0),
#  ('Dania Ramirez', 0)]

# %%
import plotly.graph_objects as go
import networkx as nx
import plotly

# %%
A = list(df["actor"].unique())
B = list(df["movie_or_TV_name"].unique())
node_list = set(A+B)

# %%
G = nx.Graph()

# %%
for i in node_list:
    G.add_node(i)

# %%
for i,j in df.iterrows():
    G.add_edges_from([(j["actor"],j["movie_or_TV_name"])])

# %%
to_be_removed = [x for  x in G.nodes() if (G.degree(x) <= 5 or G.degree(x) > 50)]
for x in to_be_removed:
    G.remove_node(x)

# %%
pos = nx.spring_layout(G, k=0.5, iterations=50)

# %%
for n, p in pos.items():
    G.nodes[n]['pos'] = p

# %%
edge_trace = go.Scatter(
    x=[],
    y=[],
    line=dict(width=0.5,color='#888'),
    hoverinfo='none',
    mode='lines')

for edge in G.edges():
    x0, y0 = G.nodes[edge[0]]['pos']
    x1, y1 = G.nodes[edge[1]]['pos']
    edge_trace['x'] += tuple([x0, x1, None])
    edge_trace['y'] += tuple([y0, y1, None])

# %%
node_trace = go.Scatter(
    x=[],
    y=[],
    text=[],
    mode='markers',
    hoverinfo='text',
    marker=dict(
        showscale=True,
        colorscale='RdBu',
        reversescale=True,
        color=[],
        size=15,
        colorbar=dict(
            thickness=10,
            title='Node Connections',
            xanchor='left',
            titleside='right'
        ),
        line=dict(width=0)))

for node in G.nodes():
    x, y = G.nodes[node]['pos']
    node_trace['x'] += tuple([x])
    node_trace['y'] += tuple([y])

# %%
for node, adjacencies in enumerate(G.adjacency()):
    node_trace['marker']['color']+=tuple([len(adjacencies[1])])
    node_info = adjacencies[0] +' # of connections: '+str(len(adjacencies[1]))
    node_trace['text']+=tuple([node_info])

# %%
fig = go.Figure(data=[edge_trace, node_trace],
             layout=go.Layout(
                title='Movie Connections based on Jumanji',
                titlefont=dict(size=20),
                title_x = 0.5,
                showlegend=False,
                hovermode='closest',
                margin=dict(b=20,l=5,r=5,t=40),
                annotations=[ dict(
                    text="No. of connections",
                    showarrow=False,
                    xref="paper", yref="paper") ],
                xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                yaxis=dict(showgrid=False, zeroline=False, showticklabels=False)))

fig.show()
# Out:
# <div>                            <div id="e38346b9-0c3b-472a-a209-ebf4aa0b3d1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e38346b9-0c3b-472a-a209-ebf4aa0b3d1e")) {                    Plotly.newPlot(                        "e38346b9-0c3b-472a-a209-ebf4aa0b3d1e",                        [{"hoverinfo":"none","line":{"color":"#888","width":0.5},"mode":"lines","type":"scatter","x":[-0.19367292115035778,-0.11543353447676082,null,-0.19367292115035778,-0.23627362700790572,null,-0.19367292115035778,-0.11663393822442122,null,-0.19367292115035778,0.10137531579577488,null,-0.19367292115035778,-0.22683118482100806,null,-0.19367292115035778,-0.4858655810596247,null,-0.6310853198685649,-0.4081525074497206,null,-0.09583542201174876,0.4110448153872587,null,-0.09583542201174876,-0.43698704075514133,null,-0.890429440749255,-0.4081525074497206,null,0.11165123240576498,-0.011138006181623679,null,0.1377571038347949,-0.23627362700790572,null,0.1377571038347949,0.4110448153872587,null,-0.23627362700790572,-0.3572313768153871,null,0.015350959720529639,0.1770466444050983,null,0.015350959720529639,-0.007359913865149624,null,0.015350959720529639,0.1833509086829734,null,0.015350959720529639,0.14983786089013024,null,0.015350959720529639,-0.011138006181623679,null,0.015350959720529639,-0.2810115713219054,null,0.4110448153872587,0.6385146734517654,null,0.4110448153872587,0.6370142921106942,null,0.4110448153872587,0.218482805042063,null,0.4110448153872587,0.8454451358081108,null,-0.27047047790281914,-0.11543353447676082,null,0.8675538897945019,0.39474174752735747,null,0.1833509086829734,0.29348197912074536,null,0.1833509086829734,0.09282947071549774,null,0.1833509086829734,-0.11944449928600555,null,0.1833509086829734,0.0036474273449944175,null,0.1833509086829734,0.06424339529647298,null,0.06424339529647298,-0.2810115713219054,null,0.06424339529647298,-0.013513653443240792,null,0.06424339529647298,0.39474174752735747,null,-0.22683118482100806,-0.4389150085280488,null,-0.22683118482100806,-0.32674015726054434,null,-0.22683118482100806,-0.11944449928600555,null,-0.22683118482100806,0.09584088130919988,null,-0.22683118482100806,0.0036474273449944175,null,0.1770466444050983,0.29348197912074536,null,0.1770466444050983,0.12318393827297726,null,0.1770466444050983,0.09282947071549774,null,0.1770466444050983,0.0036474273449944175,null,0.0036474273449944175,-0.11543353447676082,null,0.0036474273449944175,-0.013513653443240792,null,0.0036474273449944175,-0.4081525074497206,null,0.0036474273449944175,-0.11663393822442122,null,0.0036474273449944175,0.39474174752735747,null,-0.746718714389003,-0.4858655810596247,null,-0.746718714389003,-0.4081525074497206,null,-0.11663393822442122,-0.32674015726054434,null,-0.11663393822442122,-0.11944449928600555,null,-0.11663393822442122,0.09584088130919988,null,0.14983786089013024,0.29348197912074536,null,0.14983786089013024,0.12318393827297726,null,0.14983786089013024,0.09282947071549774,null,0.14983786089013024,-0.11944449928600555,null,0.14983786089013024,0.09584088130919988,null,0.29348197912074536,-0.013513653443240792,null,0.29348197912074536,0.10137531579577488,null,-0.11944449928600555,-0.007359913865149624,null,-0.11944449928600555,-0.43698704075514133,null,-0.11944449928600555,0.39474174752735747,null,-0.11944449928600555,-0.4858655810596247,null,-0.11944449928600555,-0.4081525074497206,null,-0.11944449928600555,-0.013513653443240792,null,-0.11944449928600555,-0.011138006181623679,null,0.09584088130919988,-0.007359913865149624,null,0.09584088130919988,-0.11543353447676082,null,0.09584088130919988,0.10137531579577488,null,0.09584088130919988,-0.013513653443240792,null,0.09584088130919988,0.39474174752735747,null,-0.4081525074497206,0.09282947071549774,null,0.8111693746998884,0.394741747527 ...
